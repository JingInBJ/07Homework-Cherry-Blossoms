# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time a few months, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! We don't live in Japan or DC, but we do have our fair share of the trees - buuut you sadly missed [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2019).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's a little out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows

# %%
df = pd.read_excel("KyotoFullFlower7.xls")
df
# Out:
#      Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0     This phenological data was acquired by followi...
# 1                                                   NaN
# 2                                        Column A; A.D.
# 3          Column B; Full-flowering date (day of year).
# 4     Column C; Full-flowering date (calender date, ...
# 5                                 Column D; Source code
# 6      1; Reported by Taguchi (1939), J. Marine Mete...
# 7      2; Added by Sekiguchi (1969), Tokyo Geography...
# 8      3; Added by Aono and Omoto (1994), J. Agric. ...
# 9      4; Added by Aono and Kazui (2008), Int. J. Cl...
# 10     5: Cherry phenological data, Added by Aono an...
# 11     6: Added by Aono (2011), Time Studies, 4, 17-...
# 12     7: Added by Aono (2012), Chikyu Kankyo, 17, 2...
# 13     8: Found after the last publication of articles.
# 14                             Column E; Data type code
# 15     0 : data from modern times (full-bloom date s...
# 16          1 : from diary description about full-bloom
# 17     2 : from diary description about cherry bloss...
# 18     3 : from diary description about presents of ...
# 19                          4 : title in Japanese poety
# 20     8 : Deduced from wisteria phenology, using th...
# 21     9 : Deduced from Japanese kerria phenology, u...
# 22                     Column F; Names of old documents
# 23                                                  NaN
# 24                                                   AD
# 25                                                  801
# 26                                                  802
# 27                                                  803
# 28                                                  804
# 29                                                  805
# ...                                                 ...
# 1210                                               1986
# 1211                                               1987
# 1212                                               1988
# 1213                                               1989
# 1214                                               1990
# 1215                                               1991
# 1216                                               1992
# 1217                                               1993
# 1218                                               1994
# 1219                                               1995
# 1220                                               1996
# 1221                                               1997
# 1222                                               1998
# 1223                                               1999
# 1224                                               2000
# 1225                                               2001
# 1226                                               2002
# 1227                                               2003
# 1228                                               2004
# 1229                                               2005
# 1230                                               2006
# 1231                                               2007
# 1232                                               2008
# 1233                                               2009
# 1234                                               2010
# 1235                                               2011
# 1236                                               2012
# 1237                                               2013
# 1238                                               2014
# 1239                                               2015
#
#                      Unnamed: 1           Unnamed: 2   Unnamed: 3  \
# 0                           NaN                  NaN          NaN
# 1                           NaN                  NaN          NaN
# 2                           NaN                  NaN          NaN
# 3                           NaN                  NaN          NaN
# 4                           NaN                  NaN          NaN
# 5                           NaN                  NaN          NaN
# 6                           NaN                  NaN          NaN
# 7                           NaN                  NaN          NaN
# 8                           NaN                  NaN          NaN
# 9                           NaN                  NaN          NaN
# 10                          NaN                  NaN          NaN
# 11                          NaN                  NaN          NaN
# 12                          NaN                  NaN          NaN
# 13                          NaN                  NaN          NaN
# 14                          NaN                  NaN          NaN
# 15                          NaN                  NaN          NaN
# 16                          NaN                  NaN          NaN
# 17                          NaN                  NaN          NaN
# 18                          NaN                  NaN          NaN
# 19                          NaN                  NaN          NaN
# 20                          NaN                  NaN          NaN
# 21                          NaN                  NaN          NaN
# 22                          NaN                  NaN          NaN
# 23                          NaN                  NaN          NaN
# 24    Full-flowering date (DOY)  Full-flowering date  Source code
# 25                          NaN                  NaN          NaN
# 26                          NaN                  NaN          NaN
# 27                          NaN                  NaN          NaN
# 28                          NaN                  NaN          NaN
# 29                          NaN                  NaN          NaN
# ...                         ...                  ...          ...
# 1210                        102                  412            3
# 1211                         95                  405            3
# 1212                        106                  415            3
# 1213                         93                  403            3
# 1214                         88                  329            3
# 1215                         97                  407            4
# 1216                         94                  403            4
# 1217                         97                  407            4
# 1218                         99                  409            4
# 1219                         99                  409            4
# 1220                        103                  412            4
# 1221                         97                  407            4
# 1222                         91                  401            4
# 1223                         94                  404            4
# 1224                        100                  409            4
# 1225                         96                  406            4
# 1226                         91                  401            4
# 1227                         98                  408            4
# 1228                         92                  401            4
# 1229                         99                  409            4
# 1230                         98                  408            5
# 1231                         97                  407            5
# 1232                         95                  404            6
# 1233                         95                  405            6
# 1234                         95                  405            7
# 1235                         99                  409            8
# 1236                        101                  410            8
# 1237                         93                  403            8
# 1238                         94                  404            8
# 1239                         93                  403            8
#
#           Unnamed: 4              Unnamed: 5
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# 5                NaN                     NaN
# 6                NaN                     NaN
# 7                NaN                     NaN
# 8                NaN                     NaN
# 9                NaN                     NaN
# 10               NaN                     NaN
# 11               NaN                     NaN
# 12               NaN                     NaN
# 13               NaN                     NaN
# 14               NaN                     NaN
# 15               NaN                     NaN
# 16               NaN                     NaN
# 17               NaN                     NaN
# 18               NaN                     NaN
# 19               NaN                     NaN
# 20               NaN                     NaN
# 21               NaN                     NaN
# 22               NaN                     NaN
# 23               NaN                     NaN
# 24    Data type code          Reference Name
# 25               NaN                       -
# 26               NaN                       -
# 27               NaN                       -
# 28               NaN                       -
# 29               NaN                       -
# ...              ...                     ...
# 1210               0  NEWS-PAPER(ARASHIYAMA)
# 1211               0  NEWS-PAPER(ARASHIYAMA)
# 1212               0  NEWS-PAPER(ARASHIYAMA)
# 1213               0  NEWS-PAPER(ARASHIYAMA)
# 1214               0  NEWS-PAPER(ARASHIYAMA)
# 1215               0  NEWS-PAPER(ARASHIYAMA)
# 1216               0  NEWS-PAPER(ARASHIYAMA)
# 1217               0  NEWS-PAPER(ARASHIYAMA)
# 1218               0  NEWS-PAPER(ARASHIYAMA)
# 1219               0  NEWS-PAPER(ARASHIYAMA)
# 1220               0  NEWS-PAPER(ARASHIYAMA)
# 1221               0  NEWS-PAPER(ARASHIYAMA)
# 1222               0  NEWS-PAPER(ARASHIYAMA)
# 1223               0  NEWS-PAPER(ARASHIYAMA)
# 1224               0  NEWS-PAPER(ARASHIYAMA)
# 1225               0  NEWS-PAPER(ARASHIYAMA)
# 1226               0  NEWS-PAPER(ARASHIYAMA)
# 1227               0  NEWS-PAPER(ARASHIYAMA)
# 1228               0  NEWS-PAPER(ARASHIYAMA)
# 1229               0  NEWS-PAPER(ARASHIYAMA)
# 1230               0  NEWS-PAPER(ARASHIYAMA)
# 1231               0  NEWS-PAPER(ARASHIYAMA)
# 1232               0  NEWS-PAPER(ARASHIYAMA)
# 1233               0  NEWS-PAPER(ARASHIYAMA)
# 1234               0  NEWS-PAPER(ARASHIYAMA)
# 1235               0  NEWS-PAPER(ARASHIYAMA)
# 1236               0  NEWS-PAPER(ARASHIYAMA)
# 1237               0  NEWS-PAPER(ARASHIYAMA)
# 1238               0  NEWS-PAPER(ARASHIYAMA)
# 1239               0  NEWS-PAPER(ARASHIYAMA)
#
# [1240 rows x 6 columns]

# %%
df.dtypes
#this is the original type, but the type will change after skip the first 
#several rows
# Out:
# Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)    object
# Unnamed: 1                                                                                                      object
# Unnamed: 2                                                                                                      object
# Unnamed: 3                                                                                                      object
# Unnamed: 4                                                                                                      object
# Unnamed: 5                                                                                                      object
# dtype: object

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add a parameter to make sure your columns look right.
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df=pd.read_excel("KyotoFullFlower7.xls", skiprows=25, na_values=['-','NaN'] )
df.head(5)
#why nprows=5 dont work???? 
#The column names because skiprows of 25
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
df.dtypes
#types already changed, AD changed to int, and several others to float.
# Out:
# AD                             int64
# Full-flowering date (DOY)    float64
# Full-flowering date          float64
# Source code                  float64
# Data type code               float64
# Reference Name                object
# dtype: object

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail(5)
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some more NaN values

# %% [markdown]
# It looks like you should probably have some NaN/missing values earlier on in the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %% [markdown]
# ## 4. What source is the most common as a reference?

# %%
df['Reference Name'].value_counts(ascending=False).head()
# Out:
# NEWS-PAPER(ARASHIYAMA)    94
# SUGIURAKE-NIKKI           38
# MYOHOIN-HINAMIKI          32
# OYUDONONO-UENO-NIKKI      26
# DAIGOJI-ZATSUYO           21
# Name: Reference Name, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing
#
# If you'd like to do it in two steps (which might be easier to think through), first figure out how to test whether a column is empty/missing/null/NaN, get the list of `True`/`False` values, and then later feed it to your `df`.

# %%
df['Full-flowering date (DOY)'].isnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11      False
# 12       True
# 13       True
# 14      False
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 1185    False
# 1186    False
# 1187    False
# 1188    False
# 1189    False
# 1190    False
# 1191    False
# 1192    False
# 1193    False
# 1194    False
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# 1200    False
# 1201    False
# 1202    False
# 1203    False
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# 1214    False
# Name: Full-flowering date (DOY), Length: 1215, dtype: bool

# %%
df = df.dropna(subset=['Full-flowering date (DOY)'])

# %%
df[df['Full-flowering date (DOY)'].isna()]
# Out:
# Empty DataFrame
# Columns: [AD, Full-flowering date (DOY), Full-flowering date, Source code, Data type code, Reference Name]
# Index: []

# %%
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 101    902                      102.0                412.0          5.0
# 107    908                       98.0                407.0          5.0
# 111    912                       95.0                404.0          1.0
# 112    913                      110.0                420.0          5.0
# 116    917                       95.0                405.0          1.0
# 122    923                      104.0                414.0          5.0
# 125    926                       98.0                408.0          1.0
# 129    930                       97.0                407.0          5.0
# 132    933                      106.0                416.0          5.0
# 140    941                      109.0                419.0          1.0
# 148    949                      107.0                417.0          1.0
# 149    950                       95.0                405.0          4.0
# 154    955                       89.0                330.0          5.0
# 156    957                      112.0                422.0          1.0
# 157    958                      109.0                419.0          1.0
# 158    959                       97.0                407.0          3.0
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code              Reference Name
# 11               2.0                  NIHON-KOKI
# 14               2.0                  NIHON-KOKI
# 30               2.0                  NIHON-KOKI
# 50               2.0      MONTOKUTENNO-JITSUROKU
# 52               2.0      MONTOKUTENNO-JITSUROKU
# 63               2.0     NIPPON-SANDAI-JITSUROKU
# 65               2.0     NIPPON-SANDAI-JITSUROKU
# 68               2.0                KANKE-BUNSOU
# 88               2.0     NIPPON-SANDAI-JITSUROKU
# 90               4.0                NIHONKIRYAKU
# 91               3.0         FUSHIMIIN-GOKIROKKU
# 93               2.0                KANKE-BUNSOU
# 94               4.0                NIHONKIRYAKU
# 95               4.0     NIPPON-SANDAI-JITSUROKU
# 101              8.0  EST-from-WF(NIHONGI-RYAKU)
# 107              8.0   EST-from-WF(KIMITADA-SHU)
# 111              2.0                 SHINGISHIKI
# 112              2.0                SHUI-WAKASHU
# 116              2.0                    KINHISHO
# 122              4.0          ZOKU-KOKIN-WAKASHU
# 125              2.0                NIHONKIRYAKU
# 129              8.0   EST-from-WF(SHIRYO-SORAN)
# 132              8.0   EST-from-WF(SHIRYO-SORAN)
# 140              2.0                NIHONKIRYAKU
# 148              2.0                NIHONKIRYAKU
# 149              2.0             DAINIHON-SHIRYO
# 154              4.0                     SHUISHO
# 156              2.0                NIHONKIRYAKU
# 157              2.0                NIHONKIRYAKU
# 158              2.0                     KYUREKI
# ...              ...                         ...
# 1185             0.0      NEWS-PAPER(ARASHIYAMA)
# 1186             0.0      NEWS-PAPER(ARASHIYAMA)
# 1187             0.0      NEWS-PAPER(ARASHIYAMA)
# 1188             0.0      NEWS-PAPER(ARASHIYAMA)
# 1189             0.0      NEWS-PAPER(ARASHIYAMA)
# 1190             0.0      NEWS-PAPER(ARASHIYAMA)
# 1191             0.0      NEWS-PAPER(ARASHIYAMA)
# 1192             0.0      NEWS-PAPER(ARASHIYAMA)
# 1193             0.0      NEWS-PAPER(ARASHIYAMA)
# 1194             0.0      NEWS-PAPER(ARASHIYAMA)
# 1195             0.0      NEWS-PAPER(ARASHIYAMA)
# 1196             0.0      NEWS-PAPER(ARASHIYAMA)
# 1197             0.0      NEWS-PAPER(ARASHIYAMA)
# 1198             0.0      NEWS-PAPER(ARASHIYAMA)
# 1199             0.0      NEWS-PAPER(ARASHIYAMA)
# 1200             0.0      NEWS-PAPER(ARASHIYAMA)
# 1201             0.0      NEWS-PAPER(ARASHIYAMA)
# 1202             0.0      NEWS-PAPER(ARASHIYAMA)
# 1203             0.0      NEWS-PAPER(ARASHIYAMA)
# 1204             0.0      NEWS-PAPER(ARASHIYAMA)
# 1205             0.0      NEWS-PAPER(ARASHIYAMA)
# 1206             0.0      NEWS-PAPER(ARASHIYAMA)
# 1207             0.0      NEWS-PAPER(ARASHIYAMA)
# 1208             0.0      NEWS-PAPER(ARASHIYAMA)
# 1209             0.0      NEWS-PAPER(ARASHIYAMA)
# 1210             0.0      NEWS-PAPER(ARASHIYAMA)
# 1211             0.0      NEWS-PAPER(ARASHIYAMA)
# 1212             0.0      NEWS-PAPER(ARASHIYAMA)
# 1213             0.0      NEWS-PAPER(ARASHIYAMA)
# 1214             0.0      NEWS-PAPER(ARASHIYAMA)
#
# [827 rows x 6 columns]

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date
#
# Is it not showing up? Remember the "magic" command that makes graphs show up in matplotlib notebooks!

# %%
df['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df['Full-flowering date (DOY)'].hist(bins=39)

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
df['Full-flowering date (DOY)'].describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
df_before1900 = df[df['AD'] <1900]
#or df[df.AD <1900]
df_before1900
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 101    902                      102.0                412.0          5.0
# 107    908                       98.0                407.0          5.0
# 111    912                       95.0                404.0          1.0
# 112    913                      110.0                420.0          5.0
# 116    917                       95.0                405.0          1.0
# 122    923                      104.0                414.0          5.0
# 125    926                       98.0                408.0          1.0
# 129    930                       97.0                407.0          5.0
# 132    933                      106.0                416.0          5.0
# 140    941                      109.0                419.0          1.0
# 148    949                      107.0                417.0          1.0
# 149    950                       95.0                405.0          4.0
# 154    955                       89.0                330.0          5.0
# 156    957                      112.0                422.0          1.0
# 157    958                      109.0                419.0          1.0
# 158    959                       97.0                407.0          3.0
# ...    ...                        ...                  ...          ...
# 1067  1868                      104.0                413.0          7.0
# 1068  1869                      105.0                415.0          7.0
# 1069  1870                       99.0                409.0          7.0
# 1070  1871                      104.0                414.0          7.0
# 1072  1873                      104.0                414.0          7.0
# 1073  1874                      107.0                417.0          7.0
# 1074  1875                      103.0                413.0          7.0
# 1075  1876                      111.0                420.0          7.0
# 1076  1877                      104.0                414.0          3.0
# 1077  1878                      101.0                411.0          7.0
# 1078  1879                      102.0                412.0          3.0
# 1079  1880                      110.0                419.0          3.0
# 1080  1881                      112.0                422.0          3.0
# 1081  1882                       97.0                407.0          3.0
# 1082  1883                      107.0                417.0          3.0
# 1083  1884                      109.0                418.0          3.0
# 1084  1885                      113.0                423.0          4.0
# 1085  1886                      108.0                418.0          3.0
# 1086  1887                      109.0                419.0          4.0
# 1087  1888                      107.0                416.0          4.0
# 1088  1889                      109.0                419.0          4.0
# 1089  1890                       98.0                408.0          4.0
# 1090  1891                       99.0                409.0          4.0
# 1091  1892                      115.0                424.0          4.0
# 1092  1893                      109.0                419.0          4.0
# 1093  1894                       98.0                408.0          4.0
# 1095  1896                      106.0                415.0          4.0
# 1096  1897                      106.0                416.0          4.0
# 1097  1898                      108.0                418.0          4.0
# 1098  1899                       99.0                409.0          4.0
#
#       Data type code              Reference Name
# 11               2.0                  NIHON-KOKI
# 14               2.0                  NIHON-KOKI
# 30               2.0                  NIHON-KOKI
# 50               2.0      MONTOKUTENNO-JITSUROKU
# 52               2.0      MONTOKUTENNO-JITSUROKU
# 63               2.0     NIPPON-SANDAI-JITSUROKU
# 65               2.0     NIPPON-SANDAI-JITSUROKU
# 68               2.0                KANKE-BUNSOU
# 88               2.0     NIPPON-SANDAI-JITSUROKU
# 90               4.0                NIHONKIRYAKU
# 91               3.0         FUSHIMIIN-GOKIROKKU
# 93               2.0                KANKE-BUNSOU
# 94               4.0                NIHONKIRYAKU
# 95               4.0     NIPPON-SANDAI-JITSUROKU
# 101              8.0  EST-from-WF(NIHONGI-RYAKU)
# 107              8.0   EST-from-WF(KIMITADA-SHU)
# 111              2.0                 SHINGISHIKI
# 112              2.0                SHUI-WAKASHU
# 116              2.0                    KINHISHO
# 122              4.0          ZOKU-KOKIN-WAKASHU
# 125              2.0                NIHONKIRYAKU
# 129              8.0   EST-from-WF(SHIRYO-SORAN)
# 132              8.0   EST-from-WF(SHIRYO-SORAN)
# 140              2.0                NIHONKIRYAKU
# 148              2.0                NIHONKIRYAKU
# 149              2.0             DAINIHON-SHIRYO
# 154              4.0                     SHUISHO
# 156              2.0                NIHONKIRYAKU
# 157              2.0                NIHONKIRYAKU
# 158              2.0                     KYUREKI
# ...              ...                         ...
# 1067             2.0            GAKKAI-NICHIROKU
# 1068             2.0         TAKAGI-ZAICHU-NIKKI
# 1069             1.0         TAKAGI-ZAICHU-NIKKI
# 1070             1.0         TAKAGI-ZAICHU-NIKKI
# 1072             2.0              HAYAMIKE-NIKKI
# 1073             2.0              HAYAMIKE-NIKKI
# 1074             2.0              HAYAMIKE-NIKKI
# 1075             2.0              HAYAMIKE-NIKKI
# 1076             1.0             SUGIURAKE-NIKKI
# 1077             2.0              HAYAMIKE-NIKKI
# 1078             2.0             SUGIURAKE-NIKKI
# 1079             2.0             SUGIURAKE-NIKKI
# 1080             1.0           UEKI-SHISEI-NIKKI
# 1081             1.0             SUGIURAKE-NIKKI
# 1082             2.0             SUGIURAKE-NIKKI
# 1083             2.0             SUGIURAKE-NIKKI
# 1084             2.0      NEWS-PAPER(ARASHIYAMA)
# 1085             2.0             SUGIURAKE-NIKKI
# 1086             2.0      NEWS-PAPER(ARASHIYAMA)
# 1087             0.0      NEWS-PAPER(ARASHIYAMA)
# 1088             0.0      NEWS-PAPER(ARASHIYAMA)
# 1089             0.0           UEKI-SHISEI-NIKKI
# 1090             0.0      NEWS-PAPER(ARASHIYAMA)
# 1091             0.0      NEWS-PAPER(ARASHIYAMA)
# 1092             0.0      NEWS-PAPER(ARASHIYAMA)
# 1093             0.0      NEWS-PAPER(ARASHIYAMA)
# 1095             0.0      NEWS-PAPER(ARASHIYAMA)
# 1096             0.0      NEWS-PAPER(ARASHIYAMA)
# 1097             0.0      NEWS-PAPER(ARASHIYAMA)
# 1098             0.0      NEWS-PAPER(ARASHIYAMA)
#
# [714 rows x 6 columns]

# %%
df_before1900['Full-flowering date (DOY)'].sum()/len(df_before1900.AD)
# Out:
# 105.20728291316527

# %% [markdown]
# ## 11. How about after 1900?

# %%
df_after1900 = df[df['AD'] >=1900]
#or df[df.AD >=1900]
df_after1900
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1099  1900                      102.0                412.0          4.0
# 1100  1901                      102.0                412.0          4.0
# 1101  1902                       98.0                408.0          4.0
# 1102  1903                       99.0                409.0          4.0
# 1103  1904                      108.0                417.0          4.0
# 1104  1905                      105.0                415.0          4.0
# 1105  1906                      105.0                415.0          4.0
# 1106  1907                      103.0                413.0          4.0
# 1107  1908                      102.0                411.0          4.0
# 1108  1909                      108.0                418.0          4.0
# 1109  1910                      104.0                414.0          4.0
# 1110  1911                       98.0                408.0          4.0
# 1111  1912                      105.0                414.0          4.0
# 1112  1913                      103.0                413.0          4.0
# 1113  1914                      102.0                412.0          4.0
# 1114  1915                      102.0                412.0          4.0
# 1115  1916                      112.0                421.0          4.0
# 1116  1917                      103.0                413.0          4.0
# 1117  1918                      104.0                414.0          4.0
# 1119  1920                      104.0                413.0          4.0
# 1121  1922                      101.0                411.0          4.0
# 1122  1923                       97.0                407.0          4.0
# 1123  1924                      111.0                420.0          4.0
# 1124  1925                      108.0                418.0          4.0
# 1125  1926                      108.0                418.0          4.0
# 1126  1927                      107.0                417.0          4.0
# 1127  1928                      107.0                416.0          4.0
# 1128  1929                      103.0                413.0          4.0
# 1129  1930                       95.0                405.0          4.0
# 1130  1931                      105.0                415.0          4.0
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code                            Reference Name
# 1099             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1100             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1101             0.0   KYOTO-TETUDO-KANRIKYOKU ADV(ARASHIYAMA)
# 1102             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1103             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1104             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1105             0.0   KYOTO-TETUDO-KANRIKYOKU ADV(ARASHIYAMA)
# 1106             0.0   KYOTO-TETUDO-KANRIKYOKU ADV(ARASHIYAMA)
# 1107             0.0                 TETUDOUIN AVD(ARASHIYAMA)
# 1108             0.0                 TETUDOUIN AVD(ARASHIYAMA)
# 1109             0.0                 TETUDOUIN AVD(ARASHIYAMA)
# 1110             0.0        ARASHIYAMA-TETSUDO ADV(ARASHIYAMA)
# 1111             0.0                 TETUDOUIN AVD(ARASHIYAMA)
# 1112             0.0  SEIBU-TETSUDO-KANRIKYOKU ADV(ARASHIYAMA)
# 1113             0.0   KOBE-TETSUDO-KANRIKYOKU ADV(ARASHIYAMA)
# 1114             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1115             0.0  SEIBU-TETSUDO-KANRIKYOKU ADV(ARASHIYAMA)
# 1116             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1117             0.0                         SEKI-HAJIME-NIKKI
# 1119             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1121             0.0                     KAJII-MOTOJIRO-SHOKAN
# 1122             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1123             0.0          MITAMURA-ENGYO-NIKKI(ARASHIYAMA)
# 1124             0.0            KEIHAN RAILWAY ADV(ARASHIYAMA)
# 1125             0.0            KEIHAN RAILWAY ADV(ARASHIYAMA)
# 1126             0.0            KEIHAN RAILWAY ADV(ARASHIYAMA)
# 1127             0.0            KEIHAN RAILWAY ADV(ARASHIYAMA)
# 1128             0.0       SHIN-KEIHAN RAILWAY ADV(ARASHIYAMA)
# 1129             0.0       SHIN-KEIHAN RAILWAY ADV(ARASHIYAMA)
# 1130             0.0                    NEWS-PAPER(ARASHIYAMA)
# ...              ...                                       ...
# 1185             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1186             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1187             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1188             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1189             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1190             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1191             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1192             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1193             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1194             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1195             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1196             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1197             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1198             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1199             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1200             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1201             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1202             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1203             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1204             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1205             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1206             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1207             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1208             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1209             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1210             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1211             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1212             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1213             0.0                    NEWS-PAPER(ARASHIYAMA)
# 1214             0.0                    NEWS-PAPER(ARASHIYAMA)
#
# [113 rows x 6 columns]

# %%
df_after1900['Full-flowering date (DOY)'].sum()/len(df_after1900.AD)
# Out:
# 100.32743362831859

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df_poerty = df['Data type code']==4.0
df_poerty
# Out:
# 11      False
# 14      False
# 30      False
# 50      False
# 52      False
# 63      False
# 65      False
# 68      False
# 88      False
# 90       True
# 91      False
# 93      False
# 94       True
# 95       True
# 101     False
# 107     False
# 111     False
# 112     False
# 116     False
# 122      True
# 125     False
# 129     False
# 132     False
# 140     False
# 148     False
# 149     False
# 154      True
# 156     False
# 157     False
# 158     False
#         ...
# 1185    False
# 1186    False
# 1187    False
# 1188    False
# 1189    False
# 1190    False
# 1191    False
# 1192    False
# 1193    False
# 1194    False
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# 1200    False
# 1201    False
# 1202    False
# 1203    False
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# 1214    False
# Name: Data type code, Length: 827, dtype: bool

# %%
df_poerty.value_counts()
# Out:
# False    788
# True      39
# Name: Data type code, dtype: int64

# %% [markdown]
# ## 13. Show only the years where our data was from a title in Japanese poetry

# %%
df[df['Data type code']==4.0].AD
# Out:
# 90       891
# 94       895
# 95       896
# 122      923
# 154      955
# 168      969
# 206     1007
# 232     1033
# 235     1036
# 259     1060
# 260     1061
# 283     1084
# 294     1095
# 381     1182
# 389     1190
# 400     1201
# 415     1216
# 418     1219
# 420     1221
# 422     1223
# 435     1236
# 464     1265
# 467     1268
# 468     1269
# 470     1271
# 488     1289
# 500     1301
# 523     1324
# 529     1330
# 646     1447
# 652     1453
# 653     1454
# 673     1474
# 733     1534
# 791     1592
# 839     1640
# 860     1661
# 1045    1846
# 1062    1863
# Name: AD, dtype: int64

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
df['Full-flowering date (DOY)'].plot()

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean().tail()
# Out:
# 1210    95.9
# 1211    96.9
# 1212    96.4
# 1213    96.6
# 1214    96.0
# Name: Full-flowering date (DOY), dtype: float64

# %%
# Make a new column
#not sure what the min_periods is?????
df['rolling_date']=df.rolling(20, on='AD', min_periods=1)['Full-flowering date (DOY)'].mean()
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 101    902                      102.0                412.0          5.0
# 107    908                       98.0                407.0          5.0
# 111    912                       95.0                404.0          1.0
# 112    913                      110.0                420.0          5.0
# 116    917                       95.0                405.0          1.0
# 122    923                      104.0                414.0          5.0
# 125    926                       98.0                408.0          1.0
# 129    930                       97.0                407.0          5.0
# 132    933                      106.0                416.0          5.0
# 140    941                      109.0                419.0          1.0
# 148    949                      107.0                417.0          1.0
# 149    950                       95.0                405.0          4.0
# 154    955                       89.0                330.0          5.0
# 156    957                      112.0                422.0          1.0
# 157    958                      109.0                419.0          1.0
# 158    959                       97.0                407.0          3.0
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code              Reference Name  rolling_date
# 11               2.0                  NIHON-KOKI     92.000000
# 14               2.0                  NIHON-KOKI     98.500000
# 30               2.0                  NIHON-KOKI     97.666667
# 50               2.0      MONTOKUTENNO-JITSUROKU    100.250000
# 52               2.0      MONTOKUTENNO-JITSUROKU    101.000000
# 63               2.0     NIPPON-SANDAI-JITSUROKU    100.833333
# 65               2.0     NIPPON-SANDAI-JITSUROKU    101.571429
# 68               2.0                KANKE-BUNSOU    100.750000
# 88               2.0     NIPPON-SANDAI-JITSUROKU    101.111111
# 90               4.0                NIHONKIRYAKU    101.900000
# 91               3.0         FUSHIMIIN-GOKIROKKU    102.454545
# 93               2.0                KANKE-BUNSOU    102.750000
# 94               4.0                NIHONKIRYAKU    102.846154
# 95               4.0     NIPPON-SANDAI-JITSUROKU    102.928571
# 101              8.0  EST-from-WF(NIHONGI-RYAKU)    102.866667
# 107              8.0   EST-from-WF(KIMITADA-SHU)    102.562500
# 111              2.0                 SHINGISHIKI    102.117647
# 112              2.0                SHUI-WAKASHU    102.555556
# 116              2.0                    KINHISHO    102.157895
# 122              4.0          ZOKU-KOKIN-WAKASHU    102.250000
# 125              2.0                NIHONKIRYAKU    102.550000
# 129              8.0   EST-from-WF(SHIRYO-SORAN)    102.150000
# 132              8.0   EST-from-WF(SHIRYO-SORAN)    102.650000
# 140              2.0                NIHONKIRYAKU    102.700000
# 148              2.0                NIHONKIRYAKU    102.850000
# 149              2.0             DAINIHON-SHIRYO    102.600000
# 154              4.0                     SHUISHO    101.750000
# 156              2.0                NIHONKIRYAKU    102.600000
# 157              2.0                NIHONKIRYAKU    102.850000
# 158              2.0                     KYUREKI    102.250000
# ...              ...                         ...           ...
# 1185             0.0      NEWS-PAPER(ARASHIYAMA)     99.650000
# 1186             0.0      NEWS-PAPER(ARASHIYAMA)     99.550000
# 1187             0.0      NEWS-PAPER(ARASHIYAMA)     99.900000
# 1188             0.0      NEWS-PAPER(ARASHIYAMA)     99.500000
# 1189             0.0      NEWS-PAPER(ARASHIYAMA)     98.550000
# 1190             0.0      NEWS-PAPER(ARASHIYAMA)     98.500000
# 1191             0.0      NEWS-PAPER(ARASHIYAMA)     98.250000
# 1192             0.0      NEWS-PAPER(ARASHIYAMA)     98.250000
# 1193             0.0      NEWS-PAPER(ARASHIYAMA)     98.250000
# 1194             0.0      NEWS-PAPER(ARASHIYAMA)     98.200000
# 1195             0.0      NEWS-PAPER(ARASHIYAMA)     98.400000
# 1196             0.0      NEWS-PAPER(ARASHIYAMA)     98.600000
# 1197             0.0      NEWS-PAPER(ARASHIYAMA)     97.950000
# 1198             0.0      NEWS-PAPER(ARASHIYAMA)     97.800000
# 1199             0.0      NEWS-PAPER(ARASHIYAMA)     97.700000
# 1200             0.0      NEWS-PAPER(ARASHIYAMA)     97.550000
# 1201             0.0      NEWS-PAPER(ARASHIYAMA)     97.450000
# 1202             0.0      NEWS-PAPER(ARASHIYAMA)     97.400000
# 1203             0.0      NEWS-PAPER(ARASHIYAMA)     96.550000
# 1204             0.0      NEWS-PAPER(ARASHIYAMA)     96.550000
# 1205             0.0      NEWS-PAPER(ARASHIYAMA)     96.350000
# 1206             0.0      NEWS-PAPER(ARASHIYAMA)     96.450000
# 1207             0.0      NEWS-PAPER(ARASHIYAMA)     95.900000
# 1208             0.0      NEWS-PAPER(ARASHIYAMA)     96.000000
# 1209             0.0      NEWS-PAPER(ARASHIYAMA)     96.350000
# 1210             0.0      NEWS-PAPER(ARASHIYAMA)     96.450000
# 1211             0.0      NEWS-PAPER(ARASHIYAMA)     96.800000
# 1212             0.0      NEWS-PAPER(ARASHIYAMA)     96.600000
# 1213             0.0      NEWS-PAPER(ARASHIYAMA)     96.350000
# 1214             0.0      NEWS-PAPER(ARASHIYAMA)     96.050000
#
# [827 rows x 7 columns]

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %%
df['rolling_date'].plot(ylim=(80, 120))

# %% [markdown]
# ### 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# **I've given you March as an example**, you just need to add in two more lines to do April and May.

# %%
df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'

# %%
df.loc[(df['Full-flowering date'] >400) & (df['Full-flowering date'] <500), 'month'] = 'April'

# %%
df.loc[(df['Full-flowering date'] >500),'month'] = 'May'

# %%
df.head()
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name  rolling_date  month
# 11             2.0              NIHON-KOKI     92.000000  April
# 14             2.0              NIHON-KOKI     98.500000  April
# 30             2.0              NIHON-KOKI     97.666667  April
# 50             2.0  MONTOKUTENNO-JITSUROKU    100.250000  April
# 52             2.0  MONTOKUTENNO-JITSUROKU    101.000000  April

# %% [markdown]
# ### 17. Using your new column, how many blossomings happened in each month?

# %%
df.month.value_counts()
# Out:
# April    814
# March     10
# May        3
# Name: month, dtype: int64

# %% [markdown]
# ### 18. Graph how many blossomings happened in each month.

# %%
df.month.value_counts().plot(kind='barh')

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called "day of month." It's actually a little tougher than it should be since the `Full-flowering date` column is a *float* instead of an integer.

# %%
df.head()
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name  rolling_date  month
# 11             2.0              NIHON-KOKI     92.000000  April
# 14             2.0              NIHON-KOKI     98.500000  April
# 30             2.0              NIHON-KOKI     97.666667  April
# 50             2.0  MONTOKUTENNO-JITSUROKU    100.250000  April
# 52             2.0  MONTOKUTENNO-JITSUROKU    101.000000  April

# %% [markdown]
# And if you try to convert it to an int, **pandas yells at you!**

# %% [markdown]
# That's because, as you can read, you can't have an `NaN` be an integer. But, for some reason, it *can* be a float. Ugh! So what we'll do is **drop all of the na values, then convert them to integers to get rid of the decimals.**
#
# I'll show you the first 5 here.

# %%
df['Full-flowering date'].dropna().astype(int).head()
# Out:
# 11    401
# 14    415
# 30    406
# 50    418
# 52    414
# Name: Full-flowering date, dtype: int64

# %% [markdown]
# On the next line, I take the first character of the row and add a bunch of exclamation points on it. I want you to edit this code to **return the last TWO digits of the number**. This only shows you the first 5, by the way.
#
# You might want to look up 'list slicing.'

# %%
df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[0] + "!!!").head()
# Out:
# 11    4!!!
# 14    4!!!
# 30    4!!!
# 50    4!!!
# 52    4!!!
# Name: Full-flowering date, dtype: object

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %%
df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[1:3]).head()
# Out:
# 11    01
# 14    15
# 30    06
# 50    18
# 52    14
# Name: Full-flowering date, dtype: object

# %%
df['day-of-month']=df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[1:3])

# %%
df.head()
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name  rolling_date  month day-of-month
# 11             2.0              NIHON-KOKI     92.000000  April           01
# 14             2.0              NIHON-KOKI     98.500000  April           15
# 30             2.0              NIHON-KOKI     97.666667  April           06
# 50             2.0  MONTOKUTENNO-JITSUROKU    100.250000  April           18
# 52             2.0  MONTOKUTENNO-JITSUROKU    101.000000  April           14

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`

# %%
df['date']=df['month'].str.cat(df['day-of-month'],sep='/')
df['date']
# Out:
# 11      April/01
# 14      April/15
# 30      April/06
# 50      April/18
# 52      April/14
# 63      April/09
# 65      April/16
# 68      April/05
# 88      April/14
# 90      April/19
# 91      April/17
# 93      April/16
# 94      April/14
# 95      April/13
# 101     April/12
# 107     April/07
# 111     April/04
# 112     April/20
# 116     April/05
# 122     April/14
# 125     April/08
# 129     April/07
# 132     April/16
# 140     April/19
# 148     April/17
# 149     April/05
# 154     March/30
# 156     April/22
# 157     April/19
# 158     April/07
#           ...
# 1185    April/12
# 1186    April/05
# 1187    April/15
# 1188    April/03
# 1189    March/29
# 1190    April/07
# 1191    April/03
# 1192    April/07
# 1193    April/09
# 1194    April/09
# 1195    April/12
# 1196    April/07
# 1197    April/01
# 1198    April/04
# 1199    April/09
# 1200    April/06
# 1201    April/01
# 1202    April/08
# 1203    April/01
# 1204    April/09
# 1205    April/08
# 1206    April/07
# 1207    April/04
# 1208    April/05
# 1209    April/05
# 1210    April/09
# 1211    April/10
# 1212    April/03
# 1213    April/04
# 1214    April/03
# Name: date, Length: 827, dtype: object

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
